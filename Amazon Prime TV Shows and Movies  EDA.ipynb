# %% [markdown]
# # Amazon Prime TV Shows and Movies : Exploratory Data Analysis    -

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### Name - Sandeep Prajapat

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The project aims to analyze the dataset of shows and movies available on Amazon Prime Video in the United States. By leveraging data-driven insights, the objective is to understand trends, audience preferences, and content strategies in the competitive streaming industry.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# [GitHub Link](https://github.com/Sandeep-Kumar-Prajapat/Amazon-Prime-TV-Shows-and-Movies-Exploratory-Data-Analysis)

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# This dataset was created to analyze all shows available on Amazon Prime Video in the United States, allowing us to extract valuable insights such as:
#
# * 1. Content Diversity: What genres and categories dominate the platform?
#
# * 2. Regional Availability: How does content distribution vary across different regions?
#
# * 3. Trends Over Time: How has Amazon Prime's content library evolved?
#
# * 4. IMDb Ratings & Popularity: What are the highest-rated or most popular shows on the platform?

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# In today's competitive streaming industry, platforms like Amazon Prime Video are constantly expanding their content libraries to cater to diverse audiences. The primary business objective of this project is to leverage data-driven insights to understand trends, audience preferences, and content strategy on Amazon Prime Video. By analyzing the dataset, the project aims to provide valuable insights that can help businesses, content creators, and data analysts make informed decisions regarding subscription growth, user engagement, and content investment strategies.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries

import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset

titles = pd.read_csv(r"C:\Users\sande\OneDrive\Desktop\Amazon prime movies project\titles.csv")
credits = pd.read_csv(r"C:\Users\sande\OneDrive\Desktop\Amazon prime movies project\credits.csv")

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
titles.head()
# Out:
#         id                        title   type  \
# 0  ts20945            The Three Stooges   SHOW
# 1  tm19248                  The General  MOVIE
# 2  tm82253  The Best Years of Our Lives  MOVIE
# 3  tm83884              His Girl Friday  MOVIE
# 4  tm56584            In a Lonely Place  MOVIE
#
#                                          description  release_year  \
# 0  The Three Stooges were an American vaudeville ...          1934
# 1  During America’s Civil War, Union spies steal ...          1926
# 2  It's the hope that sustains the spirit of ever...          1946
# 3  Hildy, the journalist former wife of newspaper...          1940
# 4  An aspiring actress begins to suspect that her...          1950
#
#   age_certification  runtime  \
# 0             TV-PG       19
# 1               NaN       78
# 2               NaN      171
# 3               NaN       92
# 4               NaN       94
#
#                                               genres production_countries  \
# ...

# %%
# Dataset First Look
credits.head()
# Out:
#    person_id       id           name      character   role
# 0      59401  ts20945     Joe Besser            Joe  ACTOR
# 1      31460  ts20945     Moe Howard            Moe  ACTOR
# 2      31461  ts20945     Larry Fine          Larry  ACTOR
# 3      21174  tm19248  Buster Keaton    Johnny Gray  ACTOR
# 4      28713  tm19248    Marion Mack  Annabelle Lee  ACTOR

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
titles.shape
# Out:
# (9871, 15)

# %%
# Dataset Rows & Columns count
credits.shape
# Out:
# (124235, 5)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9201 entries, 0 to 9870
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    9201 non-null   object
#  1   title                 9201 non-null   object
#  2   type                  9201 non-null   object
#  3   description           9201 non-null   object
#  4   release_year          9201 non-null   int64
#  5   age_certification     9201 non-null   object
#  6   runtime               9201 non-null   int64
#  7   genres                9201 non-null   object
#  8   production_countries  9201 non-null   object
#  9   seasons               9201 non-null   object
#  10  imdb_id               9201 non-null   object
#  11  imdb_score            9201 non-null   float64
#  12  imdb_votes            9201 non-null   float64
#  13  tmdb_popularity       9201 non-null   float64
#  14  tmdb_score            9201 non-null   float64
# ...

# %%
# Dataset Info
credits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 124179 entries, 0 to 124234
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   person_id  124179 non-null  int64
#  1   id         124179 non-null  object
#  2   name       124179 non-null  object
#  3   character  124179 non-null  object
#  4   role       124179 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 5.7+ MB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
titles.duplicated().sum()
# Out:
# np.int64(3)

# %%
# Dataset Duplicate Value Count
credits.duplicated().sum()
# Out:
# np.int64(56)

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
titles.isnull().sum()
# Out:
# id                         0
# title                      0
# type                       0
# description              119
# release_year               0
# age_certification       6487
# runtime                    0
# genres                     0
# production_countries       0
# seasons                 8514
# imdb_id                  667
# imdb_score              1021
# imdb_votes              1031
# tmdb_popularity          547
# tmdb_score              2082
# dtype: int64

# %%
# Missing Values/Null Values Count
credits.isnull().sum()
# Out:
# person_id        0
# id               0
# name             0
# character    16287
# role             0
# dtype: int64

# %%
# Visualizing the missing values
titles.isnull().sum().plot(kind='bar')
plt.show()

# %%
# Visualizing the missing values
credits.isnull().sum().plot(kind='bar')
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The dataset for Amazon Prime TV Shows and Movies Exploratory Data Analysis contains information about movies & shows available on Amazon Prime Video in the United States. It consists of two CSV files:
#
# #### 1. Titles:
#
# ID: The title ID on JustWatch.
#
# Title: The name of the title.
#
# Show Type: TV show or movie.
#
# Description: A brief description.
#
# Release Year: The release year.
#
# Age Certification: The age certification.
#
# Runtime: The length of the episode (SHOW) or movie.
#
# Genres: A list of genres.
#
# Production Countries: A list of countries that produced the title.
#
# Seasons: Number of seasons if it's a SHOW.
#
# IMDb ID: The title ID on IMDb.
#
# IMDb Score: Score on IMDb.
#
# IMDb Votes: Votes on IMDb.
#
# TMDB Popularity: Popularity on TMDB.
#
# TMDB Score: Score on TMDB.
#
# #### 2. Credits:
#
# Person ID: The person ID on JustWatch.
#
# ID: The title ID on JustWatch.
#
# Name: The actor or director's name.
#
# Character Name: The character name.
#
# Role: ACTOR or DIRECTOR.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
titles.dtypes
# Out:
# id                       object
# title                    object
# type                     object
# description              object
# release_year              int64
# age_certification        object
# runtime                   int64
# genres                   object
# production_countries     object
# seasons                 float64
# imdb_id                  object
# imdb_score              float64
# imdb_votes              float64
# tmdb_popularity         float64
# tmdb_score              float64
# dtype: object

# %%
# Dataset Columns
credits.dtypes
# Out:
# person_id     int64
# id           object
# name         object
# character    object
# role         object
# dtype: object

# %%
# Dataset Describe
titles.describe()
# Out:
#        release_year      runtime      seasons   imdb_score    imdb_votes  \
# count   9871.000000  9871.000000  1357.000000  8850.000000  8.840000e+03
# mean    2001.327221    85.973052     2.791452     5.976395  8.533614e+03
# std       25.810071    33.512466     4.148958     1.343842  4.592015e+04
# min     1912.000000     1.000000     1.000000     1.100000  5.000000e+00
# 25%     1995.500000    65.000000     1.000000     5.100000  1.170000e+02
# 50%     2014.000000    89.000000     1.000000     6.100000  4.625000e+02
# 75%     2018.000000   102.000000     3.000000     6.900000  2.236250e+03
# max     2022.000000   549.000000    51.000000     9.900000  1.133692e+06
#
#        tmdb_popularity   tmdb_score
# count      9324.000000  7789.000000
# mean          6.910204     5.984247
# std          30.004098     1.517986
# min           0.000011     0.800000
# 25%           1.232000     5.100000
# 50%           2.536000     6.000000
# 75%           5.634000     6.900000
# ...

# %%
# Dataset Describe
credits.describe()
# Out:
#           person_id
# count  1.242350e+05
# mean   4.064737e+05
# std    5.616296e+05
# min    1.000000e+00
# 25%    3.899200e+04
# 50%    1.339490e+05
# 75%    5.712560e+05
# max    2.371153e+06

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Titles CSV File:
# id: The title ID on JustWatch.
#
# title: The name of the title.
#
# show_type: TV show or movie.
#
# description: A brief description.
#
# release_year: The release year.
#
# age_certification: The age certification.
#
# runtime: The length of the episode (SHOW) or movie.
#
# genres: A list of genres.
#
# production_countries: A list of countries that produced the title.
#
# seasons: Number of seasons if it's a SHOW.
#
# imdb_id: The title ID on IMDb.
#
# imdb_score: Score on IMDb.
#
# imdb_votes: Votes on IMDb.
#
# tmdb_popularity: Popularity on TMDB.
#
# tmdb_score: Score on TMDB.
#
# Credits CSV File:
# person_id: The person ID on JustWatch.
#
# id: The title ID on JustWatch.
#
# name: The actor or director's name.
#
# character_name: The character name.
#
# role: ACTOR or DIRECTOR.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
titles.nunique()
# Out:
# id                      9868
# title                   9737
# type                       2
# description             9734
# release_year             110
# age_certification         11
# runtime                  207
# genres                  2028
# production_countries     497
# seasons                   32
# imdb_id                 9201
# imdb_score                86
# imdb_votes              3650
# tmdb_popularity         5325
# tmdb_score                89
# dtype: int64

# %%
# Check Unique Values for each variable.
credits.nunique()
# Out:
# person_id    80508
# id            8861
# name         79758
# character    71097
# role             2
# dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.


# 1. Removed Duplicated from titles dataset

titles = titles.drop_duplicates(keep = 'first')

# 2. Removed Duplicated from credits dataset

credits = credits.drop_duplicates(keep = 'first')

#### Handling Missing Values

# 3. filled NA in place of null values in column character 

credits.character = credits.character.fillna(value = 'NA')

# 4. filled NA in place of null values in column description 

titles.description = titles.description.fillna(value = 'NA')

# 5. filled NA in place of null values in column seasons 

titles.seasons = titles.seasons.fillna(value = 'NA')

# 6. filled NA in place of null values in column  age_certification

titles.age_certification = titles.age_certification.fillna(value = 'NA')

# 7. Removed Null values from column  Imdb Id

titles = titles.dropna(subset=['imdb_id'])

# 8. filled average value in place of null values in column imdb_score 

titles.imdb_score = titles.imdb_score.fillna(value = titles.imdb_score.mean())

# 9. filled median value in place of null values in column imdb_votes 

titles.imdb_votes = titles.imdb_votes.fillna(value=titles.imdb_votes.median())

# 10. filled average value in place of null values in column imdbtmdb_popularity

titles.tmdb_popularity = titles.tmdb_popularity.fillna(value=titles.tmdb_popularity.mean())

# 11. filled average value in place of null values in column tmdb_score 

titles.tmdb_score = titles.tmdb_score.fillna(value=titles.tmdb_score.mean())


# 12. merge both datasets as merged_data

merged_data = credits.merge(titles, on='id')


# 13. for converting in series

# import ast
#def convert_to_list(string):
#    return ast.literal_eval(string)

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# 1. Removed duplicate records from both titles and credits datasets.
#
#
# 2. Handled missing values:
#
# * Filled missing character values with 'NA'.
#
# * Filled missing description, seasons, and age_certification with 'NA'.
#
# * Dropped null values from imdb_id.
#
# * Replaced missing values in imdb_score, tmdb_score, and tmdb_popularity with the mean.
#
# * Replaced missing values in imdb_votes with the median.
#
#
#
# 3. Merged titles and credits datasets using the id column.
#
#
# 4. Converted list-based columns like genres and production_countries into separate values for better analysis.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1 - Frequency of Each Genre

# %%
# Chart - 1 visualization code

import ast
def convert_to_list(string):
   return ast.literal_eval(string)

titles['genres'] = titles['genres'].apply(convert_to_list)

genres_flat = [genre for sublist in titles['genres'] for genre in sublist]

from collections import Counter
genre_counts = Counter(genres_flat)
genre_counts_df = pd.DataFrame(genre_counts.items(), columns=['Genre', 'Count'])

plt.figure(figsize=(12, 8))
sns.barplot(x='Count', y='Genre', data=genre_counts_df.sort_values(by='Count', ascending=False))
plt.title('Frequency of Each Genre')
plt.xlabel('Count')
plt.ylabel('Genre')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * It effectively displays the frequency of each genre, making it easy to see which genres are most common on the platform.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Some genres, such as Drama and Comedy, are dominant, while others like Western or Documentary have lower representation.
#
# * Amazon Prime Video may need to invest in underrepresented genres to attract niche audiences.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# #### Business Impact:
#
# Investing in trending genres can increase user engagement and subscription rates.
#
#
# #### Negative Insights:
#
# Over-reliance on certain genres could limit audience expansion if not diversified.

# %% [markdown]
# #### Chart - 2  - Distribution of TV Shows vs. Movies

# %%
# Chart - 2 visualization code

labels = titles['type'].value_counts().index
sizes = titles['type'].value_counts().values

plt.figure(figsize=(8, 6))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of TV Shows vs. Movies')
plt.axis('equal')  
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The pie chart was selected to show the distribution of show types (TV shows vs. movies) as it provides a clear visual representation of proportions.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * A significantly higher proportion of movies than TV shows is available.
#
# * Amazon Prime might consider increasing TV show content to compete with Netflix.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# #### Business Impact:
#
# * Expanding TV show offerings may increase audience retention.
#
#
# #### Negative Insights:
#
# * An imbalance in content could lead to a loss of customers looking for diverse options.

# %% [markdown]
# #### Chart - 3 - Top 10 Production Country

# %%
# Chart - 3 visualization code

import ast
def convert_to_list(string):
   return ast.literal_eval(string)

titles['production_countries'] = titles['production_countries'].apply(convert_to_list)

from collections import Counter

# Assuming 'titles' is a DataFrame with a 'production_countries' column
country_flat = [country for sublist in titles['production_countries'] for country in sublist]

# Count the frequency of each country
country_counts = Counter(country_flat).most_common(10)
country_counts_df = pd.DataFrame(country_counts, columns=['production_countries', 'Count'])

plt.figure(figsize=(12, 8))
sns.barplot(x='Count', y='production_countries', data=country_counts_df.sort_values(by='Count', ascending=False))
plt.title('Top 10 Production Country')
plt.xlabel('Count')
plt.ylabel('Production Countries')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The bar plot was chosen to highlight the top 10 production countries, offering a straightforward way to compare the contributions of different countries.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The US dominates production, followed by India and the UK.
#
# * Limited representation from smaller film industries.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# #### Business Impact:
#
# * Expanding content from diverse production countries could attract international users.
#
#
# #### Negative Insights:
#
# * Over-dependence on specific regions may limit market growth.

# %% [markdown]
# #### Chart - 4 - Distribution of IMDB Ratings with Before & After Average Rating

# %%
# Chart - 4 visualization code

imdb_scores = titles['imdb_score'].dropna()

# Calculate Freedman-Diaconis bin width
q25, q75 = np.percentile(imdb_scores, [25, 75])
bin_width = 2 * (q75 - q25) * len(imdb_scores) ** (-1/3)
bins = int((imdb_scores.max() - imdb_scores.min()) / bin_width)

# Calculate mean and median
mean_score = imdb_scores.mean()
median_score = imdb_scores.median()

# Count values before and after mean
before_mean_count = (imdb_scores < mean_score).sum()
after_mean_count = (imdb_scores >= mean_score).sum()

# Set Seaborn style
sns.set_style("darkgrid")

# Create figure
plt.figure(figsize=(12, 6))

# Plot histogram with KDE
sns.histplot(imdb_scores, bins=bins, kde=True, color='royalblue', 
             edgecolor='black', alpha=0.6, linewidth=1.2)

# KDE curve customization
sns.kdeplot(imdb_scores, color='red', linestyle="--", linewidth=2)

# Add mean & median lines

plt.axvline(mean_score, color='green', linestyle='-', linewidth=2, label=f'Mean: {mean_score:.2f}')
plt.axvline(median_score, color='orange', linestyle='--', linewidth=2, label=f'Median: {median_score:.2f}')
plt.fill_betweenx(plt.ylim(), plt.xlim()[0], mean_score, color='blue', alpha=0.2, label=f'Before Mean: {before_mean_count}')
plt.fill_betweenx(plt.ylim(), mean_score, plt.xlim()[1], color='red', alpha=0.2, label=f'After Mean: {after_mean_count}')
plt.text(mean_score + 0.1, plt.ylim()[1] * 0.9, f'Mean: {mean_score:.2f}', color='green', fontsize=12, fontweight='bold')
plt.text(median_score - 0.6, plt.ylim()[1] * 0.8, f'Median: {median_score:.2f}', color='orange', fontsize=12, fontweight='bold')
plt.xlabel("IMDB Rating", fontsize=12, fontweight='bold')
plt.ylabel("Frequency", fontsize=12, fontweight='bold')
plt.title("Distribution of IMDB Ratings with Before & After Average Rating", fontsize=14, fontweight='bold')
plt.legend()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The histogram with a KDE (Kernel Density Estimate) was selected to show the distribution of IMDb ratings, allowing us to see the spread and density of ratings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Most ratings range from 5-7, indicating a large number of average-rated shows.
#
# * Few extreme ratings (either very low or very high).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# #### Business Impact:
#
# * Understanding this distribution helps Amazon Prime improve its recommendation algorithms.
#
#
# #### Negative Insights:
#
# * A lack of high-rated content may reduce user engagement.

# %% [markdown]
# #### Chart - 5 -Distribution of Roles (Actors vs. Directors)

# %%
# Chart - 5 visualization code

labels = credits['role'].value_counts().index
sizes = credits['role'].value_counts().values

# Generate colors using Seaborn palette
colors = sns.color_palette("pastel", len(labels))


plt.figure(figsize=(10, 7))
wedges, texts, autotexts = plt.pie(
    sizes, labels=labels, autopct='%1.1f%%', startangle=140, 
    colors=colors, explode=[0.05]*len(labels), shadow=True,
    wedgeprops={'edgecolor': 'black', 'linewidth': 1}
)

for text in texts + autotexts:
    text.set_fontsize(10)
    text.set_fontweight('bold')

plt.title('Distribution of Roles (Actors vs. Directors)', fontsize=14, fontweight='bold')
plt.legend(wedges, labels, title="Roles", loc="center left", bbox_to_anchor=(1, 0.5))
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The pie chart was chosen to display the distribution of roles (actors vs. directors) to easily visualize the proportion of each role.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The majority of credits belong to actors, while directors have significantly fewer records.
#
# * This could indicate the importance of actor-driven marketing.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# #### Business Impact:
#
# * Promoting high-rated directors could improve content branding.

# %% [markdown]
# #### Chart - 6 - Number of Movies Released Each Year

# %%
# Chart - 6 visualization code

movies_per_year = merged_data['release_year'].value_counts().sort_index()

plt.figure(figsize=(12, 6))
plt.bar(movies_per_year.index, movies_per_year, color='purple')
plt.xlabel('Release Year')
plt.ylabel('Number of Movies')
plt.title('Number of Movies Released Each Year')
plt.grid(True, axis='y')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The bar plot was chosen to show the number of movies released each year, making it easy to see trends over time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * A sharp increase in movie releases over the years.
#
# * Amazon has expanded its original content significantly.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# #### Business Impact:
#
# * Understanding release trends helps optimize marketing campaigns.

# %% [markdown]
# #### Chart - 7 - Top 20 Most Famous Actors (IMDb Rating)

# %%
# Chart - 7 visualization code

actors = merged_data[merged_data['role'] == 'ACTOR']
top_actors = actors.groupby('name')['imdb_score'].mean().sort_values(ascending=False).head(20)
plt.figure(figsize=(12, 8))
sns.barplot(x=top_actors.values, y=top_actors.index, palette="Blues_r",hue=top_actors.index, legend=False)
plt.title("Top 20 Most Famous Actors (IMDb Rating)", fontsize=14, fontweight='bold')
plt.xlabel("Average IMDb Rating", fontsize=12)
plt.ylabel("Actor Name", fontsize=12)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The bar plot was selected to highlight the top 20 most famous actors by IMDb rating, providing a clear comparison of their average ratings

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The highest-rated actors receive consistently good IMDb ratings.
#
# * Well-rated actors contribute to successful films.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# #### Business Impact:
#
# * Investing in movies featuring these actors can improve platform performance.

# %% [markdown]
# #### Chart - 8 - Top 10 Most Famous Directors (IMDb Rating)

# %%
# Chart - 8 visualization code

directors = merged_data[merged_data['role'] == 'DIRECTOR']
top_directors = directors.groupby('name')['imdb_score'].mean().sort_values(ascending=False).head(10)
plt.figure(figsize=(12, 8))
sns.barplot(x=top_directors.values, y=top_directors.index, palette="Reds_r",hue=top_directors.index, legend=False)
plt.title("Top 10 Most Famous Directors (IMDb Rating)", fontsize=14, fontweight='bold')
plt.xlabel("Average IMDb Rating", fontsize=12)
plt.ylabel("Director Name", fontsize=12)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The bar plot was chosen to display the top 10 most famous directors by IMDb rating, allowing for easy comparison of their average ratings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Some directors have consistently high ratings, indicating quality content.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# #### Business Impact:
#
# * Amazon should focus on signing these directors for future projects.

# %% [markdown]
# #### Chart - 9 - Top 10 Movies by IMDb and TMDb Ratings

# %%
# Chart - 9 visualization code

top_10 = titles.nlargest(10, 'imdb_score')


fig, ax = plt.subplots(figsize=(10, 6))
ax.barh(top_10['title'], top_10['imdb_score'], color='blue', alpha=0.7, label='IMDb Rating')
ax.barh(top_10['title'], top_10['tmdb_score'], color='red', alpha=0.7, label='TMDb Rating')
ax.set_xlabel('Ratings')
ax.set_title('Top 10 Movies by IMDb and TMDb Ratings')
ax.legend()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The horizontal bar plot was selected to compare the top 10 movies by both IMDb and TMDb ratings, providing a clear visual of how they rank.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The highest-rated movies align well across IMDb and TMDb.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# #### Business Impact:
#
# * These movies can be highlighted in Amazon's recommendations and promotions.

# %% [markdown]
# #### Chart - 10 - Top 10 Indian Movies by IMDb Rating

# %%
# Chart - 10 visualization code

titles['production_countries'] = titles['production_countries'].astype(str)  
indian_movies = titles[titles['production_countries'].str.contains('IN', case=False, na=False)] 
indian_movies = indian_movies[['title', 'imdb_score']].dropna().sort_values(by='imdb_score', ascending=False)


top_indian_movies = indian_movies.head(10)
plt.figure(figsize=(12, 8))
sns.barplot(x=top_indian_movies['imdb_score'], y=top_indian_movies['title'], palette="Reds_r", edgecolor='black',hue=top_indian_movies['title'], legend=False)
plt.title("Top 10 Indian Movies by IMDb Rating", fontsize=14, fontweight='bold')
plt.xlabel("IMDb Rating", fontsize=12)
plt.ylabel("Movie Title", fontsize=12)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The bar plot was chosen to show the top 10 Indian movies by IMDb rating, offering a straightforward comparison of their ratings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Indian cinema has a solid presence on Amazon Prime.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# #### Business Impact:
#
# * Promoting Indian content can increase viewership in South Asia.

# %% [markdown]
# #### Chart - 11 - Top 20 Indian Actors by IMDb Score

# %%
# Chart - 11 visualization code

merged_data['production_countries'] = merged_data['production_countries'].astype(str)  
indian_merged_data = merged_data[merged_data['production_countries'].str.contains('IN', case=False, na=False)]
indian_actors = indian_merged_data[indian_merged_data['role'] == 'ACTOR']


top_indian_actors = indian_actors.groupby('name')['imdb_score'].mean().sort_values(ascending=False).head(20)
plt.figure(figsize=(12, 6))
plt.barh(top_indian_actors.index, top_indian_actors, color='skyblue')
plt.xlabel('Average IMDb Score')
plt.title('Top 20 Indian Actors by Average IMDb Score')
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The bar plot was chosen to display the top 20 Indian actors by average IMDb score, making it easy to see which actors have the highest ratings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Bollywood actors with high IMDb ratings indicate a strong audience preference.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# #### Business Impact:
#
# * Investing in these actors for Amazon Originals can boost popularity in India.

# %% [markdown]
# #### Chart - 12 - Top 10 Indian Directors by IMDb Score

# %%
# Chart - 12 visualization code

merged_data['production_countries'] = merged_data['production_countries'].astype(str)  
indian_merged_data = merged_data[merged_data['production_countries'].str.contains('IN', case=False, na=False)]
indian_directors = indian_merged_data[indian_merged_data['role'] == 'DIRECTOR']


top_indian_directors = indian_directors.groupby('name')['imdb_score'].mean().sort_values(ascending=False).head(10)
plt.figure(figsize=(12, 6))
plt.barh(top_indian_directors.index, top_indian_directors, color='salmon')
plt.xlabel('Average IMDb Score')
plt.title('Top 10 Indian Directors by Average IMDb Score')
plt.gca().invert_yaxis() 
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The bar plot was chosen to highlight the top 10 Indian directors by average IMDb score, providing a clear comparison of their ratings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Certain directors consistently produce high-rated movies.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# #### Business Impact:
#
# * Collaborating with these directors may attract more viewers.

# %% [markdown]
# #### Chart - 13 - Top 10 Most Popular Movies (Balanced IMDb Score & Votes)

# %%
# Chart - 13 visualization code

movies = titles[(titles['type'] == 'MOVIE') & titles['imdb_score'].notna() & titles['imdb_votes'].notna()].copy()
movies.loc[:, 'popularity_log'] = movies['imdb_score'] * np.log1p(movies['imdb_votes'])
top_movies = movies[['title', 'popularity_log']].sort_values(by='popularity_log', ascending=False).head(10)
plt.figure(figsize=(12, 6))
sns.barplot(x=top_movies['popularity_log'], y=top_movies['title'], palette="coolwarm", hue=top_movies['title'], legend=False)
plt.title("Top 10 Most Popular Movies (Balanced IMDb Score & Votes)", fontsize=14, fontweight='bold')
plt.xlabel("Popularity Score (IMDb Score × log(1 + Votes))")
plt.ylabel("Movie Title")
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The bar plot was chosen to display the top 10 most popular movies, balancing IMDb score and votes to provide a clear comparison of their popularity.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Some movies maintain both high IMDb ratings and strong audience engagement.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# #### Business Impact:
#
# * Such movies should be featured prominently on Amazon’s homepage.

# %% [markdown]
# #### Chart - 14 - Top 10 Most Popular Shows (Balanced IMDb Score & Votes)

# %%
# Correlation Heatmap visualization code


shows = titles[(titles['type'] == 'SHOW') & titles['imdb_score'].notna() & titles['imdb_votes'].notna()].copy()

shows['popularity_log'] = shows['imdb_score'] * np.log1p(shows['imdb_votes'])
top_shows = shows[['title', 'popularity_log']].sort_values(by='popularity_log', ascending=False).head(10)
plt.figure(figsize=(12, 6))
sns.barplot(x=top_shows['popularity_log'], y=top_shows['title'], palette="coolwarm",hue=top_shows['title'], legend=False)

plt.title("Top 10 Most Popular Shows (Balanced IMDb Score & Votes)", fontsize=14, fontweight='bold')
plt.xlabel("Popularity Score (IMDb Score × log(1 + Votes))")
plt.ylabel("Show Title")
plt.grid(axis='x', linestyle='--', alpha=0.7)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The bar plot was chosen to display the top 10 most popular shows, balancing IMDb score and votes to provide a clear comparison of their popularity.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Similar trends as movies; audience engagement and ratings are key indicators of success*

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# 1. Diversify Content – Amazon Prime should explore underrepresented genres and countries.
#
#
# 2. Leverage High-Rated Actors & Directors – Feature popular actors and directors in Originals.
#
#
# 3. Increase TV Show Offerings – Since TV shows have high retention rates.
#
#
# 4. Improve Recommendation Algorithms – IMDb and TMDb ratings should be used for better personalized recommendations.
#
#
# 5. Optimize Content Investments – Focus on content with high audience engagement and ratings.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# The analysis provides valuable insights into content diversity, audience preferences, and IMDb/TMDb trends. By leveraging these insights, Amazon Prime Video can enhance user experience, optimize content investment, and expand its market share in the streaming industry.

# %% [markdown]
# ### ***Thank You***
